# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
seasons = pd.read_csv("number_seasons.txt")
print(seasons["Number Of Seasons"].mean())
that_show = pd.DataFrame(seasons.iloc[-1,:]).T
that_show
# Out:
# 7.020833333333333
#               Show Number Of Seasons  Number Of Episodes
# 47  That '70s Show                 8                 200

# %%
seasons
# Out:
#                                 Show  Number Of Seasons   Number Of Episodes
# 0                      Modern Family                 11                  250
# 1                            Friends                 10                  236
# 2                The Big Bang Theory                 12                  279
# 3                  All in the Family                  9                  206
# 4              How I Met Your Mother                  9                  208
# 5                            Frasier                 11                  263
# 6                               MASH                 11                  251
# 7                             Cheers                 11                  270
# 8               Arrested Development                  5                   84
# 9             The Dick Van Dyke Show                  5                  158
# 10                          Seinfeld                  9                  173
# ...

# %%
dims = (10,10)
fig, ax = plt.subplots(figsize = dims)

#sns.histplot(data=seasons, x="Number Of Seasons", kde = True)
#sns.histplot(data=that_show, x="Number Of Seasons")
sns.histplot(data=seasons, x="Number Of Episodes", fill = False, kde = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-56fcad83423b> in <module>
#       4 #sns.histplot(data=seasons, x="Number Of Seasons", kde = True)
#       5 #sns.histplot(data=that_show, x="Number Of Seasons")
# ----> 6 sns.histplot(data=seasons, x="Number Of Episodes", fill = False, kde = True)
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
dims = (10,5)
fig, ax = plt.subplots(figsize = dims)
sns.boxplot(data=seasons, x="Number Of Seasons", color = ".75")
sns.swarmplot(data=seasons, x="Number Of Seasons", color = "black")
sns.swarmplot(data=that_show, x="Number Of Seasons", color = "red", size = 10)
fig.savefig("season distribtuion.jpg")

# %%
dims = (10,5)
fig, ax = plt.subplots(figsize = dims)
sns.boxplot(data=seasons, x = "Number Of Episodes", color = ".75")
#sns.swarmplot(data=seasons, x="Number Of Seasons", color = "black")
#sns.swarmplot(data=that_show, x="Number Of Episodes", color = "red", size = 10)
#fig.savefig("season distribtuion.jpg")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-3c17c50c9c99> in <module>
#       1 dims = (10,5)
#       2 fig, ax = plt.subplots(figsize = dims)
# ----> 3 sns.boxplot(data=seasons, x = "Number Of Episodes", color = ".75")
#       4 #sns.swarmplot(data=seasons, x="Number Of Seasons", color = "black")
#       5 #sns.swarmplot(data=that_show, x="Number Of Episodes", color = "red", size = 10)
#
# D:\Bo\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2231             whis=1.5, ax=None, **kwargs):
#    2232
# -> 2233     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2234                           orient, color, palette, saturation,
#    2235                           width, dodge, fliersize, linewidth)
#
# ...

# %%
seasons["Number Of Episodes"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Bo\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number Of Episodes'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-1e50781f20f2> in <module>
# ----> 1 seasons["Number Of Episodes"]
# ...
